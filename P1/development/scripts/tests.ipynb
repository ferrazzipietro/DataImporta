# %%
import subprocess
import pandas as pd
from io import StringIO
from fastavro import json_writer, parse_schema
from datetime import datetime

from fastavro import reader


import avro.schema
from avro.datafile import DataFileReader, DataFileWriter
from avro.io import DatumReader, DatumWriter

import json

# %%
path = 'D:/Master/BDMA/Courses/Semester_2/Big_Data_Management/Project/dataimporta/'

# %%
data = subprocess.run('hadoop fs -cat /temporal/peru/imp/x14200222.csv', capture_output=True, shell=True, encoding="latin-1")

# %%
data1 = data.stdout
df = pd.read_csv(StringIO(data1))
df
# Out:
#        CADU,C,3  FANO,C,4  NDCL,C,6  FNUM,N,8,0  FEMB,N,8,0  FECH_RECEP,N,8,0  \
# 0           118      2022     10451    20220126    20220202          20220126
# 1           235      2022      7707    20220205    20220207          20220205
# 2           235      2022      7707    20220205    20220207          20220205
# 3           235      2022      7707    20220205    20220207          20220205
# 4           235      2022      7707    20220205    20220207          20220205
# ...         ...       ...       ...         ...         ...               ...
# 31659       118      2022     15615    20220208    20220214          20220208
# 31660       118      2022     15615    20220208    20220214          20220208
# 31661       118      2022     15615    20220208    20220214          20220208
# 31662       118      2022     15615    20220208    20220214          20220208
# 31663        19      2022      1263    20220131    20220131          20220131
#
#        NDCLREG,C,6  FREG,N,8,0  FANOREG,C,4  CAGE,C,4  ... VFOBSERDOL,N,11,3  \
# 0          10451.0    20220216       2022.0    8700.0  ...          35268.11
# 1           7707.0    20220214       2022.0    6199.0  ...           8138.90
# 2           7707.0    20220214       2022.0    6199.0  ...           3186.10
# 3           7707.0    20220214       2022.0    6199.0  ...           2326.75
# 4           7707.0    20220214       2022.0    6199.0  ...           2360.80
# ...            ...         ...          ...       ...  ...               ...
# 31659      15615.0    20220217       2022.0    7828.0  ...          24053.64
# 31660      15615.0    20220217       2022.0    7828.0  ...          32103.65
# 31661      15615.0    20220217       2022.0    7828.0  ...          87000.00
# 31662      15615.0    20220217       2022.0    7828.0  ...          26288.40
# 31663       1263.0    20220219       2022.0    7693.0  ...           6515.00
#
#       VPESNET,N,14,3 VPESBRU,N,14,3 QUNIFIS,N,14,3 TUNIFIS,C,10  \
# 0          23000.000      23140.000        23000.0           KG
# 1             74.797         79.636          539.0            U
# 2             29.281         31.176          211.0            U
# 3             21.383         22.767          205.0            U
# 4             21.696         23.100          208.0            U
# ...              ...            ...            ...          ...
# 31659       2721.000       2721.000         2721.0           KG
# 31660       3587.000       3587.000         3587.0           KG
# 31661      15000.000      15000.000        15000.0           KG
# 31662       4612.000       4612.000         4612.0           KG
# 31663      32200.000      32306.000        32200.0           KG
#
#        QUNICOM,N,14,3  TUNICOM,C,3 UBIGEO,C,6 DNOMCON,C,60 DDIRCON,C,80
# 0           23000.000           KG     150201          NaN          NaN
# 1             539.000            U     150132          NaN          NaN
# 2             211.000            U     150132          NaN          NaN
# 3             205.000            U     150132          NaN          NaN
# 4             208.000            U     150132          NaN          NaN
# ...               ...          ...        ...          ...          ...
# 31659           2.721           TM     150124          NaN          NaN
# 31660           3.587           TM     150124          NaN          NaN
# 31661          15.000           TM     150124          NaN          NaN
# 31662           4.612           TM     150124          NaN          NaN
# 31663       32200.000           KG      20107          NaN          NaN
#
# [31664 rows x 44 columns]

# %%
cols = list(df.columns)
fields = []
for col in cols:
    fields.append({"name":col, "type": "string"})

# %%
fields
# Out:
# [{'name': 'CADU,C,3', 'type': 'string'},
#  {'name': 'FANO,C,4', 'type': 'string'},
#  {'name': 'NDCL,C,6', 'type': 'string'},
#  {'name': 'FNUM,N,8,0', 'type': 'string'},
#  {'name': 'FEMB,N,8,0', 'type': 'string'},
#  {'name': 'FECH_RECEP,N,8,0', 'type': 'string'},
#  {'name': 'NDCLREG,C,6', 'type': 'string'},
#  {'name': 'FREG,N,8,0', 'type': 'string'},
#  {'name': 'FANOREG,C,4', 'type': 'string'},
#  {'name': 'CAGE,C,4', 'type': 'string'},
#  {'name': 'TDOC,C,1', 'type': 'string'},
#  {'name': 'NDOC,C,11', 'type': 'string'},
#  {'name': 'DNOMBRE,C,40', 'type': 'string'},
#  {'name': 'CPAIDES,C,3', 'type': 'string'},
#  {'name': 'CPUEDES,C,6', 'type': 'string'},
#  {'name': 'CVIATRA,C,1', 'type': 'string'},
#  {'name': 'CUNITRA,C,1', 'type': 'string'},
#  {'name': 'CEMPTRA,C,4', 'type': 'string'},
#  {'name': 'DMAT,C,30', 'type': 'string'},
#  {'name': 'NCON,C,20', 'type': 'string'},
#  {'name': 'CENTFIN,C,3', 'type': 'string'},
#  {'name': 'CALM,C,4', 'type': 'string'},
#  {'name': 'DNOMPRO,C,60', 'type': 'string'},
#  {'name': 'DDIRPRO,C,80', 'type': 'string'},
#  {'name': 'DK,C,1', 'type': 'string'},
#  {'name': 'DK2,C,1', 'type': 'string'},
#  {'name': 'NSER,C,4', 'type': 'string'},
#  {'name': 'PART_NANDI,N,10,0', 'type': 'string'},
#  {'name': 'DCOM,C,100', 'type': 'string'},
#  {'name': 'DMER2,C,100', 'type': 'string'},
#  {'name': 'DMER3,C,100', 'type': 'string'},
#  {'name': 'DMER4,C,100', 'type': 'string'},
#  {'name': 'DMER5,C,100', 'type': 'string'},
#  {'name': 'CEST,C,2', 'type': 'string'},
#  {'name': 'VFOBSERDOL,N,11,3', 'type': 'string'},
#  {'name': 'VPESNET,N,14,3', 'type': 'string'},
#  {'name': 'VPESBRU,N,14,3', 'type': 'string'},
#  {'name': 'QUNIFIS,N,14,3', 'type': 'string'},
#  {'name': 'TUNIFIS,C,10', 'type': 'string'},
#  {'name': 'QUNICOM,N,14,3', 'type': 'string'},
#  {'name': 'TUNICOM,C,3', 'type': 'string'},
#  {'name': 'UBIGEO,C,6', 'type': 'string'},
#  {'name': 'DNOMCON,C,60', 'type': 'string'},
#  {'name': 'DDIRCON,C,80', 'type': 'string'}]

# %%
schema = {
    "doc": datetime.now().strftime("%m/%d/%Y, %H:%M:%S"),
    "name": "trade_item",
    "namespace": "peru_imports",
    "type": "record",
    "fields": fields
}
schema = json.dumps(schema)

# %%
schema
# Out:
# '{"doc": "03/31/2022, 21:47:45", "name": "trade_item", "namespace": "peru_imports", "type": "record", "fields": [{"name": "CADU,C,3", "type": "string"}, {"name": "FANO,C,4", "type": "string"}, {"name": "NDCL,C,6", "type": "string"}, {"name": "FNUM,N,8,0", "type": "string"}, {"name": "FEMB,N,8,0", "type": "string"}, {"name": "FECH_RECEP,N,8,0", "type": "string"}, {"name": "NDCLREG,C,6", "type": "string"}, {"name": "FREG,N,8,0", "type": "string"}, {"name": "FANOREG,C,4", "type": "string"}, {"name": "CAGE,C,4", "type": "string"}, {"name": "TDOC,C,1", "type": "string"}, {"name": "NDOC,C,11", "type": "string"}, {"name": "DNOMBRE,C,40", "type": "string"}, {"name": "CPAIDES,C,3", "type": "string"}, {"name": "CPUEDES,C,6", "type": "string"}, {"name": "CVIATRA,C,1", "type": "string"}, {"name": "CUNITRA,C,1", "type": "string"}, {"name": "CEMPTRA,C,4", "type": "string"}, {"name": "DMAT,C,30", "type": "string"}, {"name": "NCON,C,20", "type": "string"}, {"name": "CENTFIN,C,3", "type": "string"}, {"name": "CALM,C,4", "type": "string"}, {"name": "DNOMPRO,C,60", "type": "string"}, {"name": "DDIRPRO,C,80", "type": "string"}, {"name": "DK,C,1", "type": "string"}, {"name": "DK2,C,1", "type": "string"}, {"name": "NSER,C,4", "type": "string"}, {"name": "PART_NANDI,N,10,0", "type": "string"}, {"name": "DCOM,C,100", "type": "string"}, {"name": "DMER2,C,100", "type": "string"}, {"name": "DMER3,C,100", "type": "string"}, {"name": "DMER4,C,100", "type": "string"}, {"name": "DMER5,C,100", "type": "string"}, {"name": "CEST,C,2", "type": "string"}, {"name": "VFOBSERDOL,N,11,3", "type": "string"}, {"name": "VPESNET,N,14,3", "type": "string"}, {"name": "VPESBRU,N,14,3", "type": "string"}, {"name": "QUNIFIS,N,14,3", "type": "string"}, {"name": "TUNIFIS,C,10", "type": "string"}, {"name": "QUNICOM,N,14,3", "type": "string"}, {"name": "TUNICOM,C,3", "type": "string"}, {"name": "UBIGEO,C,6", "type": "string"}, {"name": "DNOMCON,C,60", "type": "string"}, {"name": "DDIRCON,C,80", "type": "string"}]}'

# %%
schema = avro.schema.parse(schema)
writer = DataFileWriter(open(path+"version0.avro", "ub"), DatumWriter(), schema)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Master\BDMA\Courses\Semester_2\Big_Data_Management\Project\dataimporta\windows\tests.ipynb Cell 9' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Master/BDMA/Courses/Semester_2/Big_Data_Management/Project/dataimporta/windows/tests.ipynb#ch0000007?line=0'>1</a> schema = avro.schema.parse(schema)
# ----> <a href='vscode-notebook-cell:/d%3A/Master/BDMA/Courses/Semester_2/Big_Data_Management/Project/dataimporta/windows/tests.ipynb#ch0000007?line=1'>2</a> writer = DataFileWriter(open(path+"version0.avro", "ub"), DatumWriter(), schema)
#
# ValueError: invalid mode: 'ub'

# %%
writer.close()

# %%
records = df.to_dict('records')

# %%
load_hdfs = subprocess.run(['hadoop', 'fs', '-get', '/persistent/peru/imp/2022/version0.avro', path], capture_output=True, shell=True)

# %%
load_hdfs.returncode
# Out:
# 0

# %%
for dicts in records:
    for keys in dicts:
        dicts[keys] = str(dicts[keys])

# %%
records
# Out:
# [{'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '10451',
#   'FNUM,N,8,0': '20220126',
#   'FEMB,N,8,0': '20220202',
#   'FECH_RECEP,N,8,0': '20220126',
#   'NDCLREG,C,6': '10451.0',
#   'FREG,N,8,0': '20220216',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '8700.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20605152491',
#   'DNOMBRE,C,40': '"MAMA FOODS S.A.C"',
#   'CPAIDES,C,3': 'ES',
#   'CPUEDES,C,6': 'ECPSJ',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '7770',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'LMM0346035',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '3951.0',
#   'DNOMPRO,C,60': 'MAMA FOODS S.A.C',
#   'DDIRPRO,C,80': 'CAL. MIGUEL ALJOVIN NRO. 289 (ESPLADA DE HOSPITAL CASIMIRO ULLOA) LIMA - LIMA -',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '713399100',
#   'DCOM,C,100': 'PALLAR 920 SACOS DE 25 KG. C/U LARGE LIMA BEANS - DRIED BEANS / PALLAR EN GRANO 50/55',
#   'DMER2,C,100': 'PALLAR 920 SACOS DE 25 KG. C/U LARGE LIMA BEANS - DRIED BEANS / PALLAR EN GRANO 50/55',
#   'DMER3,C,100': 'PALLAR 920 SACOS DE 25 KG. C/U LARGE LIMA BEANS - DRIED BEANS / PALLAR EN GRANO 50/55',
#   'DMER4,C,100': 'PALLAR 920 SACOS DE 25 KG. C/U LARGE LIMA BEANS - DRIED BEANS / PALLAR EN GRANO 50/55',
#   'DMER5,C,100': 'PALLAR 920 SACOS DE 25 KG. C/U LARGE LIMA BEANS - DRIED BEANS / PALLAR EN GRANO 50/55',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '35268.11',
#   'VPESNET,N,14,3': '23000.0',
#   'VPESBRU,N,14,3': '23140.0',
#   'QUNIFIS,N,14,3': '23000.0',
#   'TUNIFIS,C,10': 'KG',
#   'QUNICOM,N,14,3': '23000.0',
#   'TUNICOM,C,3': 'KG',
#   'UBIGEO,C,6': '150201',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '7707',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220207',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '7707.0',
#   'FREG,N,8,0': '20220214',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '6199.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20603100141',
#   'DNOMBRE,C,40': '4STEXTIL S.A.C.',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USLAX',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'KE',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': '02021001745',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4372.0',
#   'DNOMPRO,C,60': '4STEXTIL S.A.C.',
#   'DDIRPRO,C,80': 'CAL. LAS GAVIOTAS MZA. B LOTE. 10J URB. LOTIZACION RUSTICA ZARATE LIMA - LIMA -',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '6206300000',
#   'DCOM,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER2,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER3,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER4,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER5,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '8138.9',
#   'VPESNET,N,14,3': '74.797',
#   'VPESBRU,N,14,3': '79.636',
#   'QUNIFIS,N,14,3': '539.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '539.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150132',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '7707',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220207',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '7707.0',
#   'FREG,N,8,0': '20220214',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '6199.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20603100141',
#   'DNOMBRE,C,40': '4STEXTIL S.A.C.',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USLAX',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'KE',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': '02021001745',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4372.0',
#   'DNOMPRO,C,60': '4STEXTIL S.A.C.',
#   'DDIRPRO,C,80': 'CAL. LAS GAVIOTAS MZA. B LOTE. 10J URB. LOTIZACION RUSTICA ZARATE LIMA - LIMA -',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '2',
#   'PART_NANDI,N,10,0': '6206300000',
#   'DCOM,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO  PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER2,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO  PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER3,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO  PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER4,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO  PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER5,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO  PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '3186.1',
#   'VPESNET,N,14,3': '29.281',
#   'VPESBRU,N,14,3': '31.176',
#   'QUNIFIS,N,14,3': '211.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '211.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150132',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '7707',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220207',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '7707.0',
#   'FREG,N,8,0': '20220214',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '6199.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20603100141',
#   'DNOMBRE,C,40': '4STEXTIL S.A.C.',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USLAX',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'KE',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': '02021001745',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4372.0',
#   'DNOMPRO,C,60': '4STEXTIL S.A.C.',
#   'DDIRPRO,C,80': 'CAL. LAS GAVIOTAS MZA. B LOTE. 10J URB. LOTIZACION RUSTICA ZARATE LIMA - LIMA -',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '3',
#   'PART_NANDI,N,10,0': '6206300000',
#   'DCOM,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER2,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER3,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER4,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER5,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '2326.75',
#   'VPESNET,N,14,3': '21.383',
#   'VPESBRU,N,14,3': '22.767',
#   'QUNIFIS,N,14,3': '205.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '205.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150132',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '7707',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220207',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '7707.0',
#   'FREG,N,8,0': '20220214',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '6199.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20603100141',
#   'DNOMBRE,C,40': '4STEXTIL S.A.C.',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USLAX',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'KE',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': '02021001745',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4372.0',
#   'DNOMPRO,C,60': '4STEXTIL S.A.C.',
#   'DDIRPRO,C,80': 'CAL. LAS GAVIOTAS MZA. B LOTE. 10J URB. LOTIZACION RUSTICA ZARATE LIMA - LIMA -',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '4',
#   'PART_NANDI,N,10,0': '6206300000',
#   'DCOM,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER2,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER3,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER4,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER5,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '2360.8',
#   'VPESNET,N,14,3': '21.696',
#   'VPESBRU,N,14,3': '23.1',
#   'QUNIFIS,N,14,3': '208.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '208.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150132',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '7707',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220207',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '7707.0',
#   'FREG,N,8,0': '20220214',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '6199.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20603100141',
#   'DNOMBRE,C,40': '4STEXTIL S.A.C.',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USLAX',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'KE',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': '02021001745',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4372.0',
#   'DNOMPRO,C,60': '4STEXTIL S.A.C.',
#   'DDIRPRO,C,80': 'CAL. LAS GAVIOTAS MZA. B LOTE. 10J URB. LOTIZACION RUSTICA ZARATE LIMA - LIMA -',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '5',
#   'PART_NANDI,N,10,0': '6206300000',
#   'DCOM,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER2,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER3,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER4,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'DMER5,C,100': 'BLUSA DE MUJER DE ALGODON. TEJIDO PLANOCODIGO N?13 RESTITUCION DE DERECHOS ARANCELARIOS',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '2485.65',
#   'VPESNET,N,14,3': '22.843',
#   'VPESBRU,N,14,3': '24.321',
#   'QUNIFIS,N,14,3': '219.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '219.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150132',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '9503002800',
#   'DCOM,C,100': 'ROPA DE MUÐECO TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'ROPA DE MUÐECO TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'ROPA DE MUÐECO TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'ROPA DE MUÐECO TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'ROPA DE MUÐECO TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '553.5',
#   'VPESNET,N,14,3': '7.361',
#   'VPESBRU,N,14,3': '7.748',
#   'QUNIFIS,N,14,3': '7.361',
#   'TUNIFIS,C,10': 'KG',
#   'QUNICOM,N,14,3': '82.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '2',
#   'PART_NANDI,N,10,0': '9503002200',
#   'DCOM,C,100': 'VESTIDO DE MUÐECA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'VESTIDO DE MUÐECA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'VESTIDO DE MUÐECA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'VESTIDO DE MUÐECA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'VESTIDO DE MUÐECA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '634.2',
#   'VPESNET,N,14,3': '8.435',
#   'VPESBRU,N,14,3': '8.879',
#   'QUNIFIS,N,14,3': '8.435',
#   'TUNIFIS,C,10': 'KG',
#   'QUNICOM,N,14,3': '151.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '3',
#   'PART_NANDI,N,10,0': '6301300000',
#   'DCOM,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1606.1',
#   'VPESNET,N,14,3': '21.361',
#   'VPESBRU,N,14,3': '22.485',
#   'QUNIFIS,N,14,3': '149.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '149.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '4',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1686.5',
#   'VPESNET,N,14,3': '22.43',
#   'VPESBRU,N,14,3': '23.611',
#   'QUNIFIS,N,14,3': '101.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '101.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '5',
#   'PART_NANDI,N,10,0': '6114200000',
#   'DCOM,C,100': 'ENTERIZO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'ENTERIZO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'ENTERIZO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'ENTERIZO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'ENTERIZO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '371.45',
#   'VPESNET,N,14,3': '4.94',
#   'VPESBRU,N,14,3': '5.2',
#   'QUNIFIS,N,14,3': '23.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '23.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '6',
#   'PART_NANDI,N,10,0': '6108310000',
#   'DCOM,C,100': 'SET DE PIJAMAS PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'SET DE PIJAMAS PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'SET DE PIJAMAS PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'SET DE PIJAMAS PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'SET DE PIJAMAS PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '3616.8',
#   'VPESNET,N,14,3': '48.102',
#   'VPESBRU,N,14,3': '50.634',
#   'QUNIFIS,N,14,3': '264.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '264.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '7',
#   'PART_NANDI,N,10,0': '6114200000',
#   'DCOM,C,100': 'ENTERIZO PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'ENTERIZO PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'ENTERIZO PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'ENTERIZO PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'ENTERIZO PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '409.5',
#   'VPESNET,N,14,3': '5.446',
#   'VPESBRU,N,14,3': '5.733',
#   'QUNIFIS,N,14,3': '26.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '26.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '8',
#   'PART_NANDI,N,10,0': '6107210000',
#   'DCOM,C,100': 'SET DE PIJAMAS PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'SET DE PIJAMAS PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'SET DE PIJAMAS PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'SET DE PIJAMAS PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'SET DE PIJAMAS PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1416.25',
#   'VPESNET,N,14,3': '18.836',
#   'VPESBRU,N,14,3': '19.827',
#   'QUNIFIS,N,14,3': '103.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '103.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '9',
#   'PART_NANDI,N,10,0': '6108310000',
#   'DCOM,C,100': 'SET DE PIJAMAS PARA DAMAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'SET DE PIJAMAS PARA DAMAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'SET DE PIJAMAS PARA DAMAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'SET DE PIJAMAS PARA DAMAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'SET DE PIJAMAS PARA DAMAS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1912.5',
#   'VPESNET,N,14,3': '25.436',
#   'VPESBRU,N,14,3': '26.775',
#   'QUNIFIS,N,14,3': '75.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '75.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '10',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1807.4',
#   'VPESNET,N,14,3': '24.038',
#   'VPESBRU,N,14,3': '25.303',
#   'QUNIFIS,N,14,3': '173.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '173.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '11',
#   'PART_NANDI,N,10,0': '6114200000',
#   'DCOM,C,100': 'BODY PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'BODY PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'BODY PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'BODY PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'BODY PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '969.5',
#   'VPESNET,N,14,3': '12.894',
#   'VPESBRU,N,14,3': '13.573',
#   'QUNIFIS,N,14,3': '92.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '92.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '12',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '366.0',
#   'VPESNET,N,14,3': '4.868',
#   'VPESBRU,N,14,3': '5.124',
#   'QUNIFIS,N,14,3': '40.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '40.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '13',
#   'PART_NANDI,N,10,0': '6104420000',
#   'DCOM,C,100': 'VESTIDO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'VESTIDO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'VESTIDO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'VESTIDO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'VESTIDO PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '3550.2',
#   'VPESNET,N,14,3': '47.216',
#   'VPESBRU,N,14,3': '49.701',
#   'QUNIFIS,N,14,3': '388.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '388.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '14',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '702.0',
#   'VPESNET,N,14,3': '9.336',
#   'VPESBRU,N,14,3': '9.827',
#   'QUNIFIS,N,14,3': '72.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '72.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '15',
#   'PART_NANDI,N,10,0': '6110201090',
#   'DCOM,C,100': 'SWETER PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'SWETER PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'SWETER PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'SWETER PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'SWETER PARA NIÐOS TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '3558.75',
#   'VPESNET,N,14,3': '47.33',
#   'VPESBRU,N,14,3': '49.821',
#   'QUNIFIS,N,14,3': '365.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '365.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '16',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'BODY PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '2067.1',
#   'VPESNET,N,14,3': '27.492',
#   'VPESBRU,N,14,3': '28.939',
#   'QUNIFIS,N,14,3': '229.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '229.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '17',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER2,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER3,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER4,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER5,C,100': 'SWETER PARA BEBES TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '116.4',
#   'VPESNET,N,14,3': '1.548',
#   'VPESBRU,N,14,3': '1.63',
#   'QUNIFIS,N,14,3': '12.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '12.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '18',
#   'PART_NANDI,N,10,0': '6110201090',
#   'DCOM,C,100': 'SWETER PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER2,C,100': 'SWETER PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER3,C,100': 'SWETER PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER4,C,100': 'SWETER PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'DMER5,C,100': 'SWETER PARA NIÐAS TEJIDO DE PUNTO, 100% ALGODON CUELLO REDONDO MANGA LARGA',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '999.1',
#   'VPESNET,N,14,3': '13.288',
#   'VPESBRU,N,14,3': '13.987',
#   'QUNIFIS,N,14,3': '103.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '103.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '19',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'VESTIDO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '2873.1',
#   'VPESNET,N,14,3': '38.211',
#   'VPESBRU,N,14,3': '40.222',
#   'QUNIFIS,N,14,3': '314.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '314.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '20',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'ENTERIZO PARA BEBES TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1303.5',
#   'VPESNET,N,14,3': '17.336',
#   'VPESBRU,N,14,3': '18.248',
#   'QUNIFIS,N,14,3': '79.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '79.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '21',
#   'PART_NANDI,N,10,0': '6301300000',
#   'DCOM,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1586.4',
#   'VPESNET,N,14,3': '21.099',
#   'VPESBRU,N,14,3': '22.21',
#   'QUNIFIS,N,14,3': '147.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '147.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '22',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '608.9',
#   'VPESNET,N,14,3': '8.097',
#   'VPESBRU,N,14,3': '8.523',
#   'QUNIFIS,N,14,3': '112.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '112.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '23',
#   'PART_NANDI,N,10,0': '6301300000',
#   'DCOM,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1445.6',
#   'VPESNET,N,14,3': '33.7',
#   'VPESBRU,N,14,3': '39.785',
#   'QUNIFIS,N,14,3': '146.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '146.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '23',
#   'PART_NANDI,N,10,0': '6301300000',
#   'DCOM,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'MANTA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1580.0',
#   'VPESNET,N,14,3': '21.013',
#   'VPESBRU,N,14,3': '22.119',
#   'QUNIFIS,N,14,3': '140.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '140.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '24',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '545.0',
#   'VPESNET,N,14,3': '12.705',
#   'VPESBRU,N,14,3': '14.998',
#   'QUNIFIS,N,14,3': '1000.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '1000.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '118',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '14601',
#   'FNUM,N,8,0': '20220205',
#   'FEMB,N,8,0': '20220208',
#   'FECH_RECEP,N,8,0': '20220205',
#   'NDCLREG,C,6': '14601.0',
#   'FREG,N,8,0': '20220219',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '7099.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20538433790',
#   'DNOMBRE,C,40': 'ABUCORP PERU SAC',
#   'CPAIDES,C,3': 'US',
#   'CPUEDES,C,6': 'USMIA',
#   'CVIATRA,C,1': '1',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '5061',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'KGLSMIA00337',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '4516.0',
#   'DNOMPRO,C,60': 'ABUCORP PERU SAC',
#   'DDIRPRO,C,80': 'CAL. CINCO NRO. 142 URB. VULCANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '24',
#   'PART_NANDI,N,10,0': '6111200000',
#   'DCOM,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER2,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER3,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER4,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'DMER5,C,100': 'BABITA TEJIDO DE PUNTO, 100% ALGODON',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '608.9',
#   'VPESNET,N,14,3': '8.097',
#   'VPESBRU,N,14,3': '8.522',
#   'QUNIFIS,N,14,3': '112.0',
#   'TUNIFIS,C,10': 'U',
#   'QUNICOM,N,14,3': '112.0',
#   'TUNICOM,C,3': 'U',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '262',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '366',
#   'FNUM,N,8,0': '20220117',
#   'FEMB,N,8,0': '20220126',
#   'FECH_RECEP,N,8,0': '20220117',
#   'NDCLREG,C,6': '366.0',
#   'FREG,N,8,0': '20220216',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '8539.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20505830319',
#   'DNOMBRE,C,40': 'ACCUAPRODUCT S.A.C.',
#   'CPAIDES,C,3': 'BO',
#   'CPUEDES,C,6': 'nan',
#   'CVIATRA,C,1': '7',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'nan',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': '3435.0',
#   'DNOMPRO,C,60': 'ACCUAPRODUCT S.A.C.',
#   'DDIRPRO,C,80': 'CAL. LOS TALABARTEROS NRO. 161 URB. EL ARTESANO LIMA - LIMA - ATE',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '3824993100',
#   'DCOM,C,100': 'ANTINCRUSTANTE ACCHEM ACC1105 MARCA:ACCHEM; MODELO: S/M; ORIGEN:REINO UNIDO N? DE LOTE 0M109;FECHA D',
#   'DMER2,C,100': 'ANTINCRUSTANTE ACCHEM ACC1105 MARCA:ACCHEM; MODELO: S/M; ORIGEN:REINO UNIDO N? DE LOTE 0M109;FECHA D',
#   'DMER3,C,100': 'ANTINCRUSTANTE ACCHEM ACC1105 MARCA:ACCHEM; MODELO: S/M; ORIGEN:REINO UNIDO N? DE LOTE 0M109;FECHA D',
#   'DMER4,C,100': 'ANTINCRUSTANTE ACCHEM ACC1105 MARCA:ACCHEM; MODELO: S/M; ORIGEN:REINO UNIDO N? DE LOTE 0M109;FECHA D',
#   'DMER5,C,100': 'ANTINCRUSTANTE ACCHEM ACC1105 MARCA:ACCHEM; MODELO: S/M; ORIGEN:REINO UNIDO N? DE LOTE 0M109;FECHA D',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '2830.0',
#   'VPESNET,N,14,3': '500.0',
#   'VPESBRU,N,14,3': '530.0',
#   'QUNIFIS,N,14,3': '500.0',
#   'TUNIFIS,C,10': 'KG',
#   'QUNICOM,N,14,3': '500.0',
#   'TUNICOM,C,3': 'KG',
#   'UBIGEO,C,6': '150103',
#   'DNOMCON,C,60': 'nan',
# ...
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '5677.8',
#   'VPESNET,N,14,3': '6785.748',
#   'VPESBRU,N,14,3': '6785.748',
#   'QUNIFIS,N,14,3': '8.484',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '2241.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4432',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220128',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4432.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'CR',
#   'CPUEDES,C,6': 'CRSJO',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '11',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '6881.26',
#   'VPESNET,N,14,3': '8224.048',
#   'VPESBRU,N,14,3': '8224.048',
#   'QUNIFIS,N,14,3': '10.281',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '2716.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4432',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220128',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4432.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'CR',
#   'CPUEDES,C,6': 'CRSJO',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '11',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '2',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '6805.25',
#   'VPESNET,N,14,3': '8133.208',
#   'VPESBRU,N,14,3': '8133.208',
#   'QUNIFIS,N,14,3': '10.168',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '2686.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4432',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220128',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4432.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'CR',
#   'CPUEDES,C,6': 'CRSJO',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '11',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '3',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '6810.32',
#   'VPESNET,N,14,3': '8139.264',
#   'VPESBRU,N,14,3': '8139.264',
#   'QUNIFIS,N,14,3': '10.175',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '2688.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4430',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220130',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4430.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'SV',
#   'CPUEDES,C,6': 'SVSAL',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '11',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '7570.4',
#   'VPESNET,N,14,3': '9047.664',
#   'VPESBRU,N,14,3': '9047.664',
#   'QUNIFIS,N,14,3': '11.311',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '2988.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4430',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220130',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4430.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'SV',
#   'CPUEDES,C,6': 'SVSAL',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '11',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '2',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '8381.15',
#   'VPESNET,N,14,3': '10016.624',
#   'VPESBRU,N,14,3': '10016.624',
#   'QUNIFIS,N,14,3': '12.522',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '3308.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4430',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220130',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4430.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'SV',
#   'CPUEDES,C,6': 'SVSAL',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '11',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '3',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '9424.99',
#   'VPESNET,N,14,3': '11264.16',
#   'VPESBRU,N,14,3': '11264.16',
#   'QUNIFIS,N,14,3': '14.082',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '3720.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4429',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220128',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4429.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'CO',
#   'CPUEDES,C,6': 'nan',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'nan',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '10659.69',
#   'VPESNET,N,14,3': '12566.2',
#   'VPESBRU,N,14,3': '12566.2',
#   'QUNIFIS,N,14,3': '15.709',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '4150.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4429',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220128',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4429.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'CO',
#   'CPUEDES,C,6': 'nan',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': 'nan',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '2',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '1474.38',
#   'VPESNET,N,14,3': '1738.072',
#   'VPESBRU,N,14,3': '1738.072',
#   'QUNIFIS,N,14,3': '2.173',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '574.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  {'CADU,C,3': '235',
#   'FANO,C,4': '2022',
#   'NDCL,C,6': '4446',
#   'FNUM,N,8,0': '20220122',
#   'FEMB,N,8,0': '20220127',
#   'FECH_RECEP,N,8,0': '20220122',
#   'NDCLREG,C,6': '4446.0',
#   'FREG,N,8,0': '20220217',
#   'FANOREG,C,4': '2022.0',
#   'CAGE,C,4': '5681.0',
#   'TDOC,C,1': '4',
#   'NDOC,C,11': '20601509416',
#   'DNOMBRE,C,40': 'AIR BP PBF DEL PERU S.A.C.',
#   'CPAIDES,C,3': 'CO',
#   'CPUEDES,C,6': 'COBOG',
#   'CVIATRA,C,1': '4',
#   'CUNITRA,C,1': 'nan',
#   'CEMPTRA,C,4': '91',
#   'DMAT,C,30': 'nan',
#   'NCON,C,20': 'nan',
#   'CENTFIN,C,3': 'nan',
#   'CALM,C,4': 'nan',
#   'DNOMPRO,C,60': 'AIR BP PBF DEL PERU S.A.C.',
#   'DDIRPRO,C,80': 'AV. RICARDO RIVERA NAVARRETE NRO. 501 INT. 1602 LIMA - LIMA - SAN ISIDRO',
#   'DK,C,1': 'nan',
#   'DK2,C,1': 'nan',
#   'NSER,C,4': '1',
#   'PART_NANDI,N,10,0': '2710191510',
#   'DCOM,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER2,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER3,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER4,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'DMER5,C,100': 'TURBO JET A1 CARBUREACTORES TIPO QUEROSENO PARA REACTORES Y TUR DESTINADOS A LAS EMPRESAS DE AVIACIO',
#   'CEST,C,2': '10',
#   'VFOBSERDOL,N,11,3': '45318.64',
#   'VPESNET,N,14,3': '54140.64',
#   'VPESBRU,N,14,3': '54140.64',
#   'QUNIFIS,N,14,3': '67.683',
#   'TUNIFIS,C,10': 'M3',
#   'QUNICOM,N,14,3': '17880.0',
#   'TUNICOM,C,3': 'GAL',
#   'UBIGEO,C,6': '70101',
#   'DNOMCON,C,60': 'nan',
#   'DDIRCON,C,80': 'nan'},
#  ...]

# %%
for record in records:
    writer.append(record)

# %%
writer.close()

# %%
# 1. List to store the records
avro_records = []

# 2. Read the Avro file
with open('users.avro', 'rb') as fo:
    avro_reader = reader(fo)
    print(avro_reader.metadata)
    for record in avro_reader:
        avro_records.append(record)
        
# 3. Convert to pd.DataFrame
df_avro = pd.DataFrame(avro_records)

# Print the first couple of rows
df_avro.head()
# Out:
# {'avro.codec': 'null', 'avro.schema': '{"type": "record", "name": "trade_item", "namespace": "peru_imports", "fields": [{"type": "string", "name": "CADU,C,3"}, {"type": "string", "name": "FANO,C,4"}, {"type": "string", "name": "NDCL,C,6"}, {"type": "string", "name": "FNUM,N,8,0"}, {"type": "string", "name": "FEMB,N,8,0"}, {"type": "string", "name": "FECH_RECEP,N,8,0"}, {"type": "string", "name": "NDCLREG,C,6"}, {"type": "string", "name": "FREG,N,8,0"}, {"type": "string", "name": "FANOREG,C,4"}, {"type": "string", "name": "CAGE,C,4"}, {"type": "string", "name": "TDOC,C,1"}, {"type": "string", "name": "NDOC,C,11"}, {"type": "string", "name": "DNOMBRE,C,40"}, {"type": "string", "name": "CPAIDES,C,3"}, {"type": "string", "name": "CPUEDES,C,6"}, {"type": "string", "name": "CVIATRA,C,1"}, {"type": "string", "name": "CUNITRA,C,1"}, {"type": "string", "name": "CEMPTRA,C,4"}, {"type": "string", "name": "DMAT,C,30"}, {"type": "string", "name": "NCON,C,20"}, {"type": "string", "name": "CENTFIN,C,3"}, {"type": "string", "name": "CALM,C,4"}, {"type": "string", "name": "DNOMPRO,C,60"}, {"type": "string", "name": "DDIRPRO,C,80"}, {"type": "string", "name": "DK,C,1"}, {"type": "string", "name": "DK2,C,1"}, {"type": "string", "name": "NSER,C,4"}, {"type": "string", "name": "PART_NANDI,N,10,0"}, {"type": "string", "name": "DCOM,C,100"}, {"type": "string", "name": "DMER2,C,100"}, {"type": "string", "name": "DMER3,C,100"}, {"type": "string", "name": "DMER4,C,100"}, {"type": "string", "name": "DMER5,C,100"}, {"type": "string", "name": "CEST,C,2"}, {"type": "string", "name": "VFOBSERDOL,N,11,3"}, {"type": "string", "name": "VPESNET,N,14,3"}, {"type": "string", "name": "VPESBRU,N,14,3"}, {"type": "string", "name": "QUNIFIS,N,14,3"}, {"type": "string", "name": "TUNIFIS,C,10"}, {"type": "string", "name": "QUNICOM,N,14,3"}, {"type": "string", "name": "TUNICOM,C,3"}, {"type": "string", "name": "UBIGEO,C,6"}, {"type": "string", "name": "DNOMCON,C,60"}, {"type": "string", "name": "DDIRCON,C,80"}], "doc": "03/31/2022, 14:33:22"}'}
#   CADU,C,3 FANO,C,4 NDCL,C,6 FNUM,N,8,0 FEMB,N,8,0 FECH_RECEP,N,8,0  \
# 0      118     2022    10451   20220126   20220202         20220126
# 1      235     2022     7707   20220205   20220207         20220205
# 2      235     2022     7707   20220205   20220207         20220205
# 3      235     2022     7707   20220205   20220207         20220205
# 4      235     2022     7707   20220205   20220207         20220205
#
#   NDCLREG,C,6 FREG,N,8,0 FANOREG,C,4 CAGE,C,4  ... VFOBSERDOL,N,11,3  \
# 0     10451.0   20220216      2022.0   8700.0  ...          35268.11
# 1      7707.0   20220214      2022.0   6199.0  ...            8138.9
# 2      7707.0   20220214      2022.0   6199.0  ...            3186.1
# 3      7707.0   20220214      2022.0   6199.0  ...           2326.75
# 4      7707.0   20220214      2022.0   6199.0  ...            2360.8
#
#   VPESNET,N,14,3 VPESBRU,N,14,3 QUNIFIS,N,14,3 TUNIFIS,C,10 QUNICOM,N,14,3  \
# 0        23000.0        23140.0        23000.0           KG        23000.0
# 1         74.797         79.636          539.0            U          539.0
# 2         29.281         31.176          211.0            U          211.0
# 3         21.383         22.767          205.0            U          205.0
# 4         21.696           23.1          208.0            U          208.0
#
#   TUNICOM,C,3 UBIGEO,C,6 DNOMCON,C,60 DDIRCON,C,80
# 0          KG     150201          nan          nan
# 1           U     150132          nan          nan
# 2           U     150132          nan          nan
# 3           U     150132          nan          nan
# 4           U     150132          nan          nan
#
# [5 rows x 44 columns]

# %%
avro_records = []

reader = DataFileReader(open("users.avro", "rb"), DatumReader())
for record in reader:
        avro_records.append(record)
        
# 3. Convert to pd.DataFrame
df_avro = pd.DataFrame(avro_records)

# Print the first couple of rows
df_avro.head()
# Out:
#   CADU,C,3 FANO,C,4 NDCL,C,6 FNUM,N,8,0 FEMB,N,8,0 FECH_RECEP,N,8,0  \
# 0      118     2022    10451   20220126   20220202         20220126
# 1      235     2022     7707   20220205   20220207         20220205
# 2      235     2022     7707   20220205   20220207         20220205
# 3      235     2022     7707   20220205   20220207         20220205
# 4      235     2022     7707   20220205   20220207         20220205
#
#   NDCLREG,C,6 FREG,N,8,0 FANOREG,C,4 CAGE,C,4  ... VFOBSERDOL,N,11,3  \
# 0     10451.0   20220216      2022.0   8700.0  ...          35268.11
# 1      7707.0   20220214      2022.0   6199.0  ...            8138.9
# 2      7707.0   20220214      2022.0   6199.0  ...            3186.1
# 3      7707.0   20220214      2022.0   6199.0  ...           2326.75
# 4      7707.0   20220214      2022.0   6199.0  ...            2360.8
#
#   VPESNET,N,14,3 VPESBRU,N,14,3 QUNIFIS,N,14,3 TUNIFIS,C,10 QUNICOM,N,14,3  \
# 0        23000.0        23140.0        23000.0           KG        23000.0
# 1         74.797         79.636          539.0            U          539.0
# 2         29.281         31.176          211.0            U          211.0
# 3         21.383         22.767          205.0            U          205.0
# 4         21.696           23.1          208.0            U          208.0
#
#   TUNICOM,C,3 UBIGEO,C,6 DNOMCON,C,60 DDIRCON,C,80
# 0          KG     150201          nan          nan
# 1           U     150132          nan          nan
# 2           U     150132          nan          nan
# 3           U     150132          nan          nan
# 4           U     150132          nan          nan
#
# [5 rows x 44 columns]

# %%
date = json.loads(reader.schema)
date["doc"]
# Out:
# '03/31/2022, 14:33:22'

# %%
date["doc"]
reader.close()

# %%
parsed_schema = parse_schema(schema)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 21' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000006untitled?line=0'>1</a> parsed_schema = parse_schema(schema)
#
# File fastavro/_schema.pyx:106, in fastavro._schema.parse_schema()
#
# File fastavro/_schema.pyx:122, in fastavro._schema._parse_schema()
#
# TypeError: unhashable type: 'RecordSchema'

# %%
parse_schema

# %%
records = df.to_dict('records')

# %%
with open('file1.avro', 'wb') as out:
    json_writer(out, parsed_schema, records)
    out.close()

# %%
# 1. List to store the records
avro_records = []

# 2. Read the Avro file
with open('file1.avro', 'rb') as fo:
    avro_reader = reader(fo)
    for record in avro_reader:
        avro_records.append(record)
        
# 3. Convert to pd.DataFrame
df_avro = pd.DataFrame(avro_records)

# Print the first couple of rows
df_avro.head()

# %%
from fastavro import writer, parse_schema

schema = {
    'doc': 'A weather reading.',
    'name': 'Weather',
    'namespace': 'test',
    'type': 'record',
    'fields': [
        {'name': 'station', 'type': 'string'},
        {'name': 'time', 'type': 'long'},
        {'name': 'temp', 'type': 'int'},
    ],
}
parsed_schema = parse_schema(schema)

records = [
    {u'station': u'011990-99999', u'temp': 0, u'time': 1433269388},
    {u'station': u'011990-99999', u'temp': 22, u'time': 1433270389},
    {u'station': u'011990-99999', u'temp': -11, u'time': 1433273379},
    {u'station': u'012650-99999', u'temp': 111, u'time': 1433275478},
]

with open('weather.avro', 'wb') as out:
    writer(out, parsed_schema, records)

# %%
# 1. List to store the records
avro_records = []

# 2. Read the Avro file
with open('weather.avro', 'rb') as fo:
    avro_reader = reader(fo)
    for record in avro_reader:
        avro_records.append(record)
        
# 3. Convert to pd.DataFrame
df_avro = pd.DataFrame(avro_records)

# Print the first couple of rows
df_avro.head()

# %%
# CLEAN FOLDERS INSIDE HADOOP

#PERU

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/peru/exp/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/peru/exp/'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/peru/imp/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/peru/imp/'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/peru/metadata/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/peru/metadata/'], capture_output=True, shell=True)

#BRAZIL

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/brazil/exp/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/brazil/exp/'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/brazil/imp/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/brazil/imp/'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/brazil/metadata/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/brazil/metadata/'], capture_output=True, shell=True)

#CHILE

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/chile/exp/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/chile/exp/'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/chile/imp/'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/chile/imp/'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/chile/metadata/imp'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/chile/metadata/imp'], capture_output=True, shell=True)

subprocess.run(['hadoop', 'fs', '-rm', '-r', '/persistent/chile/metadata/exp'], capture_output=True, shell=True)
subprocess.run(['hadoop', 'fs', '-mkdir', '/persistent/chile/metadata/exp'], capture_output=True, shell=True)
# Out:
# CompletedProcess(args=['hadoop', 'fs', '-mkdir', '/persistent/chile/metadata/exp'], returncode=0, stdout=b'', stderr=b'')
